# %%
import os
import json

# %%
path = "/Users/kunal/Documents/AzureCompetition/data.json"

# %%
os.rename(path, "/Users/kunal/Documents/AzureCompetition/data.txt")

# %%
path = "/Users/kunal/Documents/AzureCompetition/data.txt"

# %%
str = open('path.txt', 'r').read()

# %%
data
# Out:
# ''

# %%
rrr.
# Out:
# '{\n    "Location": {\n        "LocationInformation": {\n            "PanoID": "Dj2vLK2UVexr4quxGEY3zg",\n            "Latitude": 40.7086397,\n            "Longitude": -74.0052092,\n            "Address": "New York City, New York, , US",\n            "ContainsSideWalk": {\n                "0": true,\n                "90": true,\n                "180": true,\n                "270": true\n            }\n        },\n        "Img1_0": {\n            "Direction_Degrees": 0,\n            "EncodedImg": "...",\n            "Pitch": 0,\n            "ZoomAndFov": 75,\n            "CalculatedOutputAzure": {\n                "ImageTagging": {\n                    "Tags": {\n                        "road": {\n                            "Confidence": 99.85784888267517,\n                            "Hint": "None"\n                        },\n                        "outdoor": {\n                            "Confidence": 99.36063289642334,\n                            "Hint": "None"\n              
# ...

# %%
import json


    data = json.load(f)

# %%
with open(path,) as f:
    d = json.loads(f)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-18-d4003d8e02d2> in <module>
#       1 with open(path,) as f:
# ----> 2     d = json.loads(f)
#
# c:\users\kunal\appdata\local\programs\python\python38\lib\json\__init__.py in loads(s, cls, object_hook, parse_float, parse_int, parse_constant, object_pairs_hook, **kw)
#     339     else:
#     340         if not isinstance(s, (bytes, bytearray)):
# --> 341             raise TypeError(f'the JSON object must be str, bytes or bytearray, '
#     342                             f'not {s.__class__.__name__}')
#     343         s = s.decode(detect_encoding(s), 'surrogatepass')
#
# TypeError: the JSON object must be str, bytes or bytearray, not TextIOWrapper

# %%
data['id'] = 134 # <--- add `id` value.
    f.seek(0)        # <--- should reset file position to the beginning.
    json.dump(data, f, indent=4)
    f.truncate()
